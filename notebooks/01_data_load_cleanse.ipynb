# %% [markdown]
# # Data Load & Cleansing
# In this notebook, we will load the sample data and investigate the content. We will also cleanse the data. We first import the packages we will be using and then we load the sample data. We are using the `consumer_id` column as the index column for the data frame under the assumption this field contains unique values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
pd.plotting.register_matplotlib_converters()

file_path = "../data/data.csv"
data = pd.read_csv(file_path, index_col = "consumer_id")

# %% [markdown]
# First five rows of the dataframe looks like below. We can easily see that we have some `NaN` values. We will look into these columns with `NaN` values later when we are cleansing the data.

# %%
data.head()
# Out:
#                                      gender  has_gender  has_first_name  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8    NaN           0               1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04    NaN           0               1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40    NaN           0               1
# 12c2e02f-bc79-4048-83ba-359cd3280dcf    NaN           0               1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f      f           1               1
#
#                                       has_last_name  has_email  has_dob  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8              1          1        0
# 128af162-d2c3-4fe4-986c-359c8bdc6c04              1          1        0
# 12aada5e-36eb-4e9e-8d62-359c076c1b40              1          1        0
# 12c2e02f-bc79-4048-83ba-359cd3280dcf              1          1        0
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f              1          1        1
#
#                                       customer_age  account_age  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8           NaN          188
# 128af162-d2c3-4fe4-986c-359c8bdc6c04           NaN          185
# 12aada5e-36eb-4e9e-8d62-359c076c1b40           NaN          188
# 12c2e02f-bc79-4048-83ba-359cd3280dcf           NaN          184
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f          22.0          572
#
#                                       account_last_updated  account_status  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                   174               0
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                   174               0
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                   174               0
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                   174               0
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                   173               0
#
#                                       app_downloads  unique_offer_clicked  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8              1                     3
# 128af162-d2c3-4fe4-986c-359c8bdc6c04              1                     3
# 12aada5e-36eb-4e9e-8d62-359c076c1b40              1                     3
# 12c2e02f-bc79-4048-83ba-359cd3280dcf              1                     3
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f              1                     4
#
#                                       total_offer_clicks  unique_offer_rides  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                   3                   8
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                   8                   5
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                   4                   9
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                   7                   4
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                   6                   7
#
#                                       total_offer_rides  avg_claims  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                 52         1.0
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                 58         1.0
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                183         1.0
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                 56         1.0
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                 83         1.0
#
#                                       min_claims  max_claims  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8           1           1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04           1           1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40           1           1
# 12c2e02f-bc79-4048-83ba-359cd3280dcf           1           1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f           1           1
#
#                                       total_offers_claimed
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                     1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                     1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                     3
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                     1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                     3

# %% [markdown]
# Lets separate object and numeric columns.

# %%
obj_cols = [col for col in data.columns if data[col].dtype == "object"]
num_cols = [col for col in data.columns if data[col].dtype in ["int64", "float64"]]

# %% [markdown]
# We can see that the only object column is the `gender` column.

# %%
print(num_cols, obj_cols)
# Out:
# ['has_gender', 'has_first_name', 'has_last_name', 'has_email', 'has_dob', 'customer_age', 'account_age', 'account_last_updated', 'account_status', 'app_downloads', 'unique_offer_clicked', 'total_offer_clicks', 'unique_offer_rides', 'total_offer_rides', 'avg_claims', 'min_claims', 'max_claims', 'total_offers_claimed'] ['gender']

# %% [markdown]
# Let's also get those columns with `NaN` values. It looks like there are only two columns with `NaN` values.

# %%
obj_cols_with_na = [col for col in obj_cols if data[col].isnull().any()]
num_cols_with_na = [col for col in num_cols if data[col].isnull().any()]

print(obj_cols_with_na, num_cols_with_na)
# Out:
# ['gender'] ['customer_age']

# %% [markdown]
# We define the following function to get the percent of number of `NaN` values in those columns with `NaN` values.

# %%
def na_ratio(col):
    ratio = col.isnull().sum() / len(col)
    if (ratio > 0):
        return ratio
    
data[obj_cols_with_na + num_cols_with_na].apply(na_ratio)
# Out:
# gender          0.4522
# customer_age    0.5936
# dtype: float64

# %% [markdown]
# These ratios are rather high. And, there is almost no way to figure out the missing data. Imputation would remove most of the data. Since we have two columns (`has_gender` and `has_dob`) that indicate if the record has a gender or age, we will be dropping the `gender` and `customer_age` columns. In addition, we will also drop `account_status` column as it has only one single value.

# %%
data.drop(obj_cols_with_na + num_cols_with_na + ["account_status"], axis = 1, inplace = True)

data.head()
# Out:
#                                       has_gender  has_first_name  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8           0               1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04           0               1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40           0               1
# 12c2e02f-bc79-4048-83ba-359cd3280dcf           0               1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f           1               1
#
#                                       has_last_name  has_email  has_dob  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8              1          1        0
# 128af162-d2c3-4fe4-986c-359c8bdc6c04              1          1        0
# 12aada5e-36eb-4e9e-8d62-359c076c1b40              1          1        0
# 12c2e02f-bc79-4048-83ba-359cd3280dcf              1          1        0
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f              1          1        1
#
#                                       account_age  account_last_updated  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8          188                   174
# 128af162-d2c3-4fe4-986c-359c8bdc6c04          185                   174
# 12aada5e-36eb-4e9e-8d62-359c076c1b40          188                   174
# 12c2e02f-bc79-4048-83ba-359cd3280dcf          184                   174
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f          572                   173
#
#                                       app_downloads  unique_offer_clicked  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8              1                     3
# 128af162-d2c3-4fe4-986c-359c8bdc6c04              1                     3
# 12aada5e-36eb-4e9e-8d62-359c076c1b40              1                     3
# 12c2e02f-bc79-4048-83ba-359cd3280dcf              1                     3
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f              1                     4
#
#                                       total_offer_clicks  unique_offer_rides  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                   3                   8
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                   8                   5
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                   4                   9
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                   7                   4
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                   6                   7
#
#                                       total_offer_rides  avg_claims  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                 52         1.0
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                 58         1.0
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                183         1.0
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                 56         1.0
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                 83         1.0
#
#                                       min_claims  max_claims  \
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8           1           1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04           1           1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40           1           1
# 12c2e02f-bc79-4048-83ba-359cd3280dcf           1           1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f           1           1
#
#                                       total_offers_claimed
# consumer_id
# 1284b75c-ecae-4015-8e3d-359c0347ede8                     1
# 128af162-d2c3-4fe4-986c-359c8bdc6c04                     1
# 12aada5e-36eb-4e9e-8d62-359c076c1b40                     3
# 12c2e02f-bc79-4048-83ba-359cd3280dcf                     1
# 12fabdf0-0582-489e-a6d3-35509ab8ae6f                     3
